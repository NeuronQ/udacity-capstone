# %% [markdown]
# # BTC-USD @5min

# %%
# PARAMS:
BC5M_FILENAME = './data_clean/btc.300s.cbpro.csv'
# TL;DR change params & Kernel > Restart & Run All to "run this like a script"

# %%
# autoreload
# %load_ext autoreload
# %autoreload 1
# write code that works in both Python 2 (2.7+) and 3 (3.5+)
from __future__ import absolute_import, division, print_function, unicode_literals
try:
    input = raw_input
    range = xrange
except NameError:
    pass

# %%
import os
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

import keras
from keras.layers.core import Dense, Activation, Dropout
from keras.layers.recurrent import LSTM
from keras.models import Sequential

import pprint
pp = pprint.PrettyPrinter(indent=2).pprint
from IPython.display import display as dd
from IPython.display import Image

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
# %aimport lib.helpers
# %aimport lib.etl
# %aimport lib.visualization
# %aimport lib.walk_forward_predict
# %aimport models.rnn
# %aimport models.lr
from lib.helpers import (
    timing, print_shapes, fix_all_rngs,
    date_str_to_ts
)
from lib.visualization import simple_plot
from lib.walk_forward_predict import (
    run_walk_forward_validation_rnn,
    run_walk_forward_validation_arima,
    run_walk_forward_validation_rnn_retraining
)
import lib.etl as etl
from models.rnn import make_rnn_model_constructor
from models.lr import LRModel

# %%
data5m = pd.read_csv(
    BC5M_FILENAME,
    index_col='timestamp',
    parse_dates=['datetime']
)
print('> size:', len(data5m))
dd(data5m.dtypes)
dd(data5m.head())
dd(data5m.tail())
simple_plot(data5m, xticks_span=30 * 24 * 60 // 3)
# Out:
# > size: 387948
# datetime    datetime64[ns]
# low                float64
# high               float64
# open               float64
# close              float64
# volume             float64
# dtype: object
#                       datetime     low    high    open   close      volume
# timestamp
# 1422745200 2015-01-31 23:00:00  224.51  225.69  225.38  224.51   29.638700
# 1422745500 2015-01-31 23:05:00  224.00  225.59  224.62  224.00   52.189176
# 1422745800 2015-01-31 23:10:00  221.99  223.92  223.91  221.99   40.262566
# 1422746100 2015-01-31 23:15:00  218.00  222.00  222.00  218.00  163.490760
# 1422746400 2015-01-31 23:20:00  217.11  218.89  217.92  218.22   96.317898
#                       datetime      low     high     open    close     volume
# timestamp
# 1539128100 2018-10-09 23:35:00  6590.30  6593.48  6591.54  6590.30  17.148190
# 1539128400 2018-10-09 23:40:00  6586.55  6590.31  6590.31  6589.30  15.269094
# 1539128700 2018-10-09 23:45:00  6589.29  6589.69  6589.30  6589.48  12.466310
# 1539129000 2018-10-09 23:50:00  6589.47  6592.81  6589.48  6591.85  14.972801
# 1539129300 2018-10-09 23:55:00  6589.47  6592.81  6591.84  6589.48  31.305392

# %% [markdown]
# ## Test runs (laptop)

# %% [markdown]
# ### LSTM

# %%
with timing('run experiment'):
    run_walk_forward_validation_rnn(
        # data to extract:
        data5m,
        features=['close', 'open', 'high', 'low', 'volume'],
        from_i=0,
        train_sz=25000,
        test_sz=3000,
        # data processing:
        normalize='seqs',  # 'seqs' | 'data'
        detrend=False,
        # model and prediction arrangement:
        seq_len=100,
        pred_len=100,
        model_maker=make_rnn_model_constructor([100, 0.1, 50, 0.1]),
        # training:
        epochs=3,
        batch_size=512,
        shuffle=False,
        # experiment setup:
        times=1,
        skip=True,
        fix_all_rngs_to=False,
        fix_rngs_before_each=False,
        # plotting:
        fig_size=(10, 8),
        fast=True,
    )
# Out:
# data ~ (28000, 5)
# --- 0.014s to model compilation time
#
#
# --- Created model id: 140530269845648
# Tensor("lstm_1_input:0", shape=(?, 100, 5), dtype=float32)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 100, 100)          42400
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 100, 100)          0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 50)                30200
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 72,651
# Trainable params: 72,651
# Non-trainable params: 0
# _________________________________________________________________
# None
# Tensor("dense_1/BiasAdd:0", shape=(?, 1), dtype=float32)
#
# Train on 23654 samples, validate on 1245 samples
# Epoch 1/3
# 23654/23654 [==============================] - 28s 1ms/step - loss: 0.0070 - val_loss: 8.0976e-04
# Epoch 2/3
# 23654/23654 [==============================] - 33s 1ms/step - loss: 0.0018 - val_loss: 6.9406e-05
# Epoch 3/3
# 23654/23654 [==============================] - 34s 1ms/step - loss: 7.7905e-04 - val_loss: 4.9436e-05
# --- 94.823s to train model
#
# --- 2.586s to walk and predict
#
# --- 0.037s to plot incremental predictions
# --- 98.911s to run experiment

# %%
with timing('run experiment'):
    run_walk_forward_validation_rnn(
        # data to extract:
        data5m,
        features=['close', 'open', 'high', 'low', 'volume'],
        from_i=99000,
        train_sz=25000,
        test_sz=3000,
        # data processing:
        normalize='seqs',  # 'seqs' | 'data'
        detrend=False,
        # model and prediction arrangement:
        seq_len=100,
        pred_len=100,
        model_maker=make_rnn_model_constructor([100, 0.1, 50, 0.1]),
        # training:
        epochs=3,
        batch_size=512,
        shuffle=False,
        # experiment setup:
        times=1,
        skip=True,
        fix_all_rngs_to=False,
        fix_rngs_before_each=False,
        # plotting:
        fig_size=(10, 8),
        fast=True,
    )
# Out:
# data ~ (28000, 5)
# --- 0.020s to model compilation time
#
#
# --- Created model id: 140530127721744
# Tensor("lstm_3_input:0", shape=(?, 100, 5), dtype=float32)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_3 (LSTM)                (None, 100, 100)          42400
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 100, 100)          0
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 50)                30200
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 72,651
# Trainable params: 72,651
# Non-trainable params: 0
# _________________________________________________________________
# None
# Tensor("dense_2/BiasAdd:0", shape=(?, 1), dtype=float32)
#
# Train on 23654 samples, validate on 1245 samples
# Epoch 1/3
# 23654/23654 [==============================] - 29s 1ms/step - loss: 0.0078 - val_loss: 3.0318e-05
# Epoch 2/3
# 23654/23654 [==============================] - 34s 1ms/step - loss: 0.0015 - val_loss: 1.3426e-05
# Epoch 3/3
# 23654/23654 [==============================] - 36s 2ms/step - loss: 6.5686e-04 - val_loss: 1.7190e-05
# --- 100.709s to train model
#
# --- 2.667s to walk and predict
#
# --- 0.038s to plot incremental predictions
# --- 105.004s to run experiment

# %%
with timing('run experiment'):
    run_walk_forward_validation_rnn(
        # data to extract:
        data5m,
        features=['close', 'open', 'high', 'low', 'volume'],
        from_i=198000,
        train_sz=25000,
        test_sz=3000,
        # data processing:
        normalize='seqs',  # 'seqs' | 'data'
        detrend=False,
        # model and prediction arrangement:
        seq_len=100,
        pred_len=100,
        model_maker=make_rnn_model_constructor([100, 0.1, 50, 0.1]),
        # training:
        epochs=3,
        batch_size=512,
        shuffle=False,
        # experiment setup:
        times=1,
        skip=True,
        fix_all_rngs_to=False,
        fix_rngs_before_each=False,
        # plotting:
        fig_size=(10, 8),
        fast=True,
    )
# Out:
# data ~ (28000, 5)
# --- 0.023s to model compilation time
#
#
# --- Created model id: 140530127186512
# Tensor("lstm_5_input:0", shape=(?, 100, 5), dtype=float32)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_5 (LSTM)                (None, 100, 100)          42400
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 100, 100)          0
# _________________________________________________________________
# lstm_6 (LSTM)                (None, 50)                30200
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 72,651
# Trainable params: 72,651
# Non-trainable params: 0
# _________________________________________________________________
# None
# Tensor("dense_3/BiasAdd:0", shape=(?, 1), dtype=float32)
#
# Train on 23654 samples, validate on 1245 samples
# Epoch 1/3
# 23654/23654 [==============================] - 37s 2ms/step - loss: 0.0087 - val_loss: 0.0091
# Epoch 2/3
# 23654/23654 [==============================] - 41s 2ms/step - loss: 0.0019 - val_loss: 0.0042
# Epoch 3/3
# 23654/23654 [==============================] - 41s 2ms/step - loss: 9.4665e-04 - val_loss: 0.0012
# --- 119.206s to train model
#
# --- 3.259s to walk and predict
#
# --- 0.050s to plot incremental predictions
# --- 124.349s to run experiment

# %%
with timing('run experiment'):
    run_walk_forward_validation_rnn(
        # data to extract:
        data5m,
        features=['close', 'open', 'high', 'low', 'volume'],
        from_i=300000,
        train_sz=25000,
        test_sz=3000,
        # data processing:
        normalize='seqs',  # 'seqs' | 'data'
        detrend=False,
        # model and prediction arrangement:
        seq_len=100,
        pred_len=100,
        model_maker=make_rnn_model_constructor([100, 0.1, 50, 0.1]),
        # training:
        epochs=3,
        batch_size=512,
        shuffle=False,
        # experiment setup:
        times=1,
        skip=True,
        fix_all_rngs_to=False,
        fix_rngs_before_each=False,
        # plotting:
        fig_size=(10, 8),
        fast=True,
    )
# Out:
# data ~ (28000, 5)
# --- 0.026s to model compilation time
#
#
# --- Created model id: 140529913781520
# Tensor("lstm_7_input:0", shape=(?, 100, 5), dtype=float32)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_7 (LSTM)                (None, 100, 100)          42400
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 100, 100)          0
# _________________________________________________________________
# lstm_8 (LSTM)                (None, 50)                30200
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 72,651
# Trainable params: 72,651
# Non-trainable params: 0
# _________________________________________________________________
# None
# Tensor("dense_4/BiasAdd:0", shape=(?, 1), dtype=float32)
#
# Train on 23654 samples, validate on 1245 samples
# Epoch 1/3
# 23654/23654 [==============================] - 38s 2ms/step - loss: 0.0040 - val_loss: 1.7020e-04
# Epoch 2/3
# 23654/23654 [==============================] - 30s 1ms/step - loss: 0.0012 - val_loss: 7.0319e-04
# Epoch 3/3
# 23654/23654 [==============================] - 33s 1ms/step - loss: 6.2965e-04 - val_loss: 8.9308e-04
# --- 102.718s to train model
#
# --- 2.548s to walk and predict
#
# --- 0.036s to plot incremental predictions
# --- 107.542s to run experiment

# %% [markdown]
# ## 6 epochs

# %%
with timing('run experiment'):
    run_walk_forward_validation_rnn(
        # data to extract:
        data5m,
        features=['close', 'open', 'high', 'low', 'volume'],
        from_i=0,
        train_sz=25000,
        test_sz=3000,
        # data processing:
        normalize='seqs',  # 'seqs' | 'data'
        detrend=False,
        # model and prediction arrangement:
        seq_len=100,
        pred_len=100,
        model_maker=make_rnn_model_constructor([100, 0.1, 50, 0.1]),
        # training:
        epochs=6,
        batch_size=512,
        shuffle=False,
        # experiment setup:
        times=1,
        skip=True,
        fix_all_rngs_to=False,
        fix_rngs_before_each=False,
        # plotting:
        fig_size=(10, 8),
        fast=True,
    )
# Out:
# data ~ (28000, 5)
# --- 0.017s to model compilation time
#
#
# --- Created model id: 140530127261776
# Tensor("lstm_9_input:0", shape=(?, 100, 5), dtype=float32)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_9 (LSTM)                (None, 100, 100)          42400
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 100, 100)          0
# _________________________________________________________________
# lstm_10 (LSTM)               (None, 50)                30200
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 50)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 72,651
# Trainable params: 72,651
# Non-trainable params: 0
# _________________________________________________________________
# None
# Tensor("dense_5/BiasAdd:0", shape=(?, 1), dtype=float32)
#
# Train on 23654 samples, validate on 1245 samples
# Epoch 1/6
# 23654/23654 [==============================] - 30s 1ms/step - loss: 0.0215 - val_loss: 0.0020
# Epoch 2/6
# 23654/23654 [==============================] - 34s 1ms/step - loss: 0.0027 - val_loss: 1.9806e-04
# Epoch 3/6
# 23654/23654 [==============================] - 32s 1ms/step - loss: 0.0014 - val_loss: 3.0117e-04
# Epoch 4/6
# 23654/23654 [==============================] - 33s 1ms/step - loss: 8.3241e-04 - val_loss: 8.1237e-05
# Epoch 5/6
# 23654/23654 [==============================] - 35s 1ms/step - loss: 3.6589e-04 - val_loss: 3.9157e-05
# Epoch 6/6
# 23654/23654 [==============================] - 36s 2ms/step - loss: 2.5002e-04 - val_loss: 4.3007e-05
# --- 200.624s to train model
#
# --- 2.839s to walk and predict
#
# --- 0.040s to plot incremental predictions
# --- 205.117s to run experiment

# %%
with timing('run experiment'):
    run_walk_forward_validation_rnn(
        # data to extract:
        data5m,
        features=['close', 'open', 'high', 'low', 'volume'],
        from_i=99000,
        train_sz=25000,
        test_sz=3000,
        # data processing:
        normalize='seqs',  # 'seqs' | 'data'
        detrend=False,
        # model and prediction arrangement:
        seq_len=100,
        pred_len=100,
        model_maker=make_rnn_model_constructor([100, 0.1, 50, 0.1]),
        # training:
        epochs=6,
        batch_size=512,
        shuffle=False,
        # experiment setup:
        times=1,
        skip=True,
        fix_all_rngs_to=False,
        fix_rngs_before_each=False,
        # plotting:
        fig_size=(10, 8),
        fast=True,
    )
# Out:
# data ~ (28000, 5)
# --- 0.022s to model compilation time
#
#
# --- Created model id: 140529876120208
# Tensor("lstm_11_input:0", shape=(?, 100, 5), dtype=float32)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_11 (LSTM)               (None, 100, 100)          42400
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 100, 100)          0
# _________________________________________________________________
# lstm_12 (LSTM)               (None, 50)                30200
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 50)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 72,651
# Trainable params: 72,651
# Non-trainable params: 0
# _________________________________________________________________
# None
# Tensor("dense_6/BiasAdd:0", shape=(?, 1), dtype=float32)
#
# Train on 23654 samples, validate on 1245 samples
# Epoch 1/6
# 23654/23654 [==============================] - 39s 2ms/step - loss: 0.0082 - val_loss: 1.2646e-04
# Epoch 2/6
# 23654/23654 [==============================] - 41s 2ms/step - loss: 0.0016 - val_loss: 2.7522e-05
# Epoch 3/6
# 23654/23654 [==============================] - 39s 2ms/step - loss: 6.8236e-04 - val_loss: 1.0544e-05
# Epoch 4/6
# 23654/23654 [==============================] - 41s 2ms/step - loss: 3.5994e-04 - val_loss: 7.9585e-06
# Epoch 5/6
# 23654/23654 [==============================] - 38s 2ms/step - loss: 2.3959e-04 - val_loss: 3.1210e-06
# Epoch 6/6
# 23654/23654 [==============================] - 38s 2ms/step - loss: 1.6600e-04 - val_loss: 4.0322e-06
# --- 237.807s to train model
#
# --- 3.057s to walk and predict
#
# --- 0.311s to plot incremental predictions
# --- 243.012s to run experiment

# %%
with timing('run experiment'):
    run_walk_forward_validation_rnn(
        # data to extract:
        data5m,
        features=['close', 'open', 'high', 'low', 'volume'],
        from_i=198000,
        train_sz=25000,
        test_sz=3000,
        # data processing:
        normalize='seqs',  # 'seqs' | 'data'
        detrend=False,
        # model and prediction arrangement:
        seq_len=100,
        pred_len=100,
        model_maker=make_rnn_model_constructor([100, 0.1, 50, 0.1]),
        # training:
        epochs=6,
        batch_size=512,
        shuffle=False,
        # experiment setup:
        times=1,
        skip=True,
        fix_all_rngs_to=False,
        fix_rngs_before_each=False,
        # plotting:
        fig_size=(10, 8),
        fast=True,
    )
# Out:
# data ~ (28000, 5)
# --- 0.027s to model compilation time
#
#
# --- Created model id: 140529913643600
# Tensor("lstm_13_input:0", shape=(?, 100, 5), dtype=float32)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_13 (LSTM)               (None, 100, 100)          42400
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 100, 100)          0
# _________________________________________________________________
# lstm_14 (LSTM)               (None, 50)                30200
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 50)                0
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 72,651
# Trainable params: 72,651
# Non-trainable params: 0
# _________________________________________________________________
# None
# Tensor("dense_7/BiasAdd:0", shape=(?, 1), dtype=float32)
#
# Train on 23654 samples, validate on 1245 samples
# Epoch 1/6
# 23654/23654 [==============================] - 40s 2ms/step - loss: 0.0053 - val_loss: 0.0031
# Epoch 2/6
# 23654/23654 [==============================] - 40s 2ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 3/6
# 23654/23654 [==============================] - 41s 2ms/step - loss: 6.2236e-04 - val_loss: 0.0012
# Epoch 4/6
# 23654/23654 [==============================] - 39s 2ms/step - loss: 4.1205e-04 - val_loss: 9.4748e-04
# Epoch 5/6
# 23654/23654 [==============================] - 40s 2ms/step - loss: 2.9289e-04 - val_loss: 4.4933e-04
# Epoch 6/6
# 23654/23654 [==============================] - 39s 2ms/step - loss: 2.3199e-04 - val_loss: 5.2133e-04
# --- 240.743s to train model
#
# --- 3.351s to walk and predict
#
# --- 0.050s to plot incremental predictions
# --- 246.123s to run experiment

# %%
with timing('run experiment'):
    run_walk_forward_validation_rnn(
        # data to extract:
        data5m,
        features=['close', 'open', 'high', 'low', 'volume'],
        from_i=300000,
        train_sz=25000,
        test_sz=3000,
        # data processing:
        normalize='seqs',  # 'seqs' | 'data'
        detrend=False,
        # model and prediction arrangement:
        seq_len=100,
        pred_len=100,
        model_maker=make_rnn_model_constructor([100, 0.1, 50, 0.1]),
        # training:
        epochs=6,
        batch_size=512,
        shuffle=False,
        # experiment setup:
        times=1,
        skip=True,
        fix_all_rngs_to=False,
        fix_rngs_before_each=False,
        # plotting:
        fig_size=(10, 8),
        fast=True,
    )
# Out:
# data ~ (28000, 5)
# --- 0.029s to model compilation time
#
#
# --- Created model id: 140527173250832
# Tensor("lstm_15_input:0", shape=(?, 100, 5), dtype=float32)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_15 (LSTM)               (None, 100, 100)          42400
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 100, 100)          0
# _________________________________________________________________
# lstm_16 (LSTM)               (None, 50)                30200
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 50)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 72,651
# Trainable params: 72,651
# Non-trainable params: 0
# _________________________________________________________________
# None
# Tensor("dense_8/BiasAdd:0", shape=(?, 1), dtype=float32)
#
# Train on 23654 samples, validate on 1245 samples
# Epoch 1/6
# 23654/23654 [==============================] - 40s 2ms/step - loss: 0.0069 - val_loss: 0.0072
# Epoch 2/6
# 23654/23654 [==============================] - 37s 2ms/step - loss: 0.0015 - val_loss: 2.5316e-04
# Epoch 3/6
# 23654/23654 [==============================] - 37s 2ms/step - loss: 7.8121e-04 - val_loss: 0.0025
# Epoch 4/6
# 23654/23654 [==============================] - 37s 2ms/step - loss: 5.5456e-04 - val_loss: 2.5059e-05
# Epoch 5/6
# 23654/23654 [==============================] - 36s 2ms/step - loss: 3.8178e-04 - val_loss: 1.0449e-04
# Epoch 6/6
# 23654/23654 [==============================] - 39s 2ms/step - loss: 2.9568e-04 - val_loss: 2.2490e-04
# --- 227.632s to train model
#
# --- 3.102s to walk and predict
#
# --- 0.041s to plot incremental predictions
# --- 232.879s to run experiment
